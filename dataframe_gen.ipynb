# %%
import librosa as lr
from IPython.display import Audio
import numpy as np
import pandas as pd
import os
import seaborn as sns

# %%
# Load patient id numbers and corresponding diseases
patient_data = pd.read_csv(r"C:\Users\Anil Sharma\Documents\archive\Respiratory_Sound_Database\Respiratory_Sound_Database\patient_diagnosis.csv", names = ['pid', 'disease'])
patient_data.head()
# Out:
#    pid  disease
# 0  101     URTI
# 1  102  Healthy
# 2  103   Asthma
# 3  104     COPD
# 4  105     URTI

# %%
# Load text files containing patient annotations for each sound recording 
path = r'C:\Users\Anil Sharma\Documents\archive\Respiratory_Sound_Database\Respiratory_Sound_Database\audio_and_txt_files'
file_names = [s.split(',')[0] for s in os.listdir(path) if '.txt' in s] # Put all file names in list

files_data=[]
for file in file_names:
    file_data = pd.read_csv(path + '\\' + file, sep = '\t',names=['start','end','crackles','wheezes'])
    name_data = file.split('_')
    file_data['pid'] = name_data[0]
    file_data['mode'] = name_data[-2]
    file_data['filename'] = file
    file_data['recording_location'] = name_data[-3]
    file_data['recording_device'] = name_data[4].split('.')[0]
    files_data.append(file_data)
files_df=pd.concat(files_data)
files_df.reset_index()
files_df
# Out:
#      start     end  crackles  wheezes  pid mode                    filename  \
# 0    0.036   0.579         0        0  101   sc  101_1b1_Al_sc_Meditron.txt
# 1    0.579   2.450         0        0  101   sc  101_1b1_Al_sc_Meditron.txt
# 2    2.450   3.893         0        0  101   sc  101_1b1_Al_sc_Meditron.txt
# 3    3.893   5.793         0        0  101   sc  101_1b1_Al_sc_Meditron.txt
# 4    5.793   7.521         0        0  101   sc  101_1b1_Al_sc_Meditron.txt
# ..     ...     ...       ...      ...  ...  ...                         ...
# 6   11.721  13.693         1        0  226   sc  226_1b1_Pl_sc_LittC2SE.txt
# 7   13.693  15.536         0        0  226   sc  226_1b1_Pl_sc_LittC2SE.txt
# 8   15.536  17.493         0        0  226   sc  226_1b1_Pl_sc_LittC2SE.txt
# 9   17.493  19.436         1        0  226   sc  226_1b1_Pl_sc_LittC2SE.txt
# 10  19.436  19.979         0        0  226   sc  226_1b1_Pl_sc_LittC2SE.txt
#
#    recording_location recording_device
# 0                  Al         Meditron
# 1                  Al         Meditron
# 2                  Al         Meditron
# 3                  Al         Meditron
# 4                  Al         Meditron
# ..                ...              ...
# 6                  Pl         LittC2SE
# 7                  Pl         LittC2SE
# 8                  Pl         LittC2SE
# 9                  Pl         LittC2SE
# 10                 Pl         LittC2SE
#
# [6898 rows x 9 columns]

# %%
# Merge patient disease with annotation dataframe
files_df['pid'] = files_df['pid'].astype('int32')
patient_data['pid'] = patient_data['pid'].astype('int32')
df = pd.merge(files_df, patient_data, on = 'pid')
df
# Out:
#        start     end  crackles  wheezes  pid mode                    filename  \
# 0      0.036   0.579         0        0  101   sc  101_1b1_Al_sc_Meditron.txt
# 1      0.579   2.450         0        0  101   sc  101_1b1_Al_sc_Meditron.txt
# 2      2.450   3.893         0        0  101   sc  101_1b1_Al_sc_Meditron.txt
# 3      3.893   5.793         0        0  101   sc  101_1b1_Al_sc_Meditron.txt
# 4      5.793   7.521         0        0  101   sc  101_1b1_Al_sc_Meditron.txt
# ...      ...     ...       ...      ...  ...  ...                         ...
# 6893  11.721  13.693         1        0  226   sc  226_1b1_Pl_sc_LittC2SE.txt
# 6894  13.693  15.536         0        0  226   sc  226_1b1_Pl_sc_LittC2SE.txt
# 6895  15.536  17.493         0        0  226   sc  226_1b1_Pl_sc_LittC2SE.txt
# 6896  17.493  19.436         1        0  226   sc  226_1b1_Pl_sc_LittC2SE.txt
# 6897  19.436  19.979         0        0  226   sc  226_1b1_Pl_sc_LittC2SE.txt
#
#      recording_location recording_device    disease
# 0                    Al         Meditron       URTI
# 1                    Al         Meditron       URTI
# 2                    Al         Meditron       URTI
# 3                    Al         Meditron       URTI
# 4                    Al         Meditron       URTI
# ...                 ...              ...        ...
# 6893                 Pl         LittC2SE  Pneumonia
# 6894                 Pl         LittC2SE  Pneumonia
# 6895                 Pl         LittC2SE  Pneumonia
# 6896                 Pl         LittC2SE  Pneumonia
# 6897                 Pl         LittC2SE  Pneumonia
#
# [6898 rows x 10 columns]

# %%
# Export dataframe
df.to_csv(r'C:\Users\Anil Sharma\Documents\dataframe.csv')

# %%
# Gives me number of crackles, wheezes, both symptoms, and no labels in all dataset
no_label_list = []
crack_list = []
wheeze_list = []
both_sym_list = []
filename_list = []
for i in range(len(df)):
    no_labels = len(df[(df['crackles'] == 0) & (df['wheezes'] == 0)].index)
    n_crackles = len(df[(df['crackles'] == 1) & (df['wheezes'] == 0)].index)
    n_wheezes = len(df[(df['crackles'] == 0) & (df['wheezes'] == 1)].index)
    both_sym = len(df[(df['crackles'] == 1) & (df['wheezes'] == 1)].index)

# %%
print(no_labels, n_crackles, n_wheezes, both_sym)
# Out:
# 3642 1864 886 506
